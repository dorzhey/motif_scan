# %%
from motif_scanner import MotifScanner


scanner = MotifScanner(species="human")
result_table = scanner.scan("test.fasta")

# Display the results
print(result_table)
# Out:
#   sequence_id  gc_content                                  kmer_distribution  \
# 0        seq1   52.941176  {'ATG': 1, 'TGC': 1, 'GCG': 1, 'CGT': 3, 'GTA'...
# 1        seq2   60.000000  {'CGT': 2, 'GTA': 2, 'TAC': 1, 'ACG': 1, 'TAG'...
#
#                                        tf_idf_scores  \
# 0  {'ATG': 0.046209812037329684, 'TGC': 0.0462098...
# 1  {'ATG': 0.046209812037329684, 'TGC': 0.0462098...
#
#                                         top_5_motifs
# 0  {'ARNT_HUMAN.H11MO.0.B': 2.1967442525442022, '...
# 1  {'ARNT_HUMAN.H11MO.0.B': 0.45896482170823527, ...

# %%
from visualize_results import visualize_results
visualize_results(result_table)
